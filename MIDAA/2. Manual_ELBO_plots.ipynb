# %% [markdown]
# # Plotting ELBOs to identify best MIDAA model
# This notebook provides the code to identify the best MIDAA models from the saved outputs, following running the MIDAA modeol in the MIDAA_pipeline notebook. The number of arhcetyeps impacts the latent space and resulting polytope. The number that best perofrms on ELBO score while not being so high it compromises interpretabiltiy is the ideal model. This can be identified using the elbow of final ELBO plots. This happens automatically on the MIDAA_pipeline notebook, but also put here in case its helpful to track progress before all the range of archetypes have been built.
#
#
# You can run this pipeline on a base environment.
# The pipeline requiers original adata and paths to the saved .pkl files for the models to be plotted
#
# The notebook has been developed with  using https://sottorivalab.github.io/midaa/scMulti_multimodal.html for instruction on MIDAA application, and LLMs to aid code writing and concept explanations where required

# %% [markdown]
# ## 1. Load data and models
# Loading the adata object and pretrained models

# %%
import torch
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt
from scipy.sparse import issparse
import os
import pickle

# %%
# Load AnnData object
# adata_path = r"C:\Users\DG1\Desktop\DALLAB\Experimenting\Data\Antibiotic resistance\BacDrop\further processing\adata_balanced_gentamicin_distribution_min_per_bin.h5ad"
adata_path = r"C:\Users\DG1\Desktop\DALLAB\Experimenting\Data\Pancreatic Data\Input_Data\Adata\TUMOUR_bivona_clean_adata.h5ad"
adata = sc.read_h5ad(adata_path)
print(f'Loaded AnnData with shape: {adata.shape}') #QC

# %%
#loading pretrained models --> update with yours (path numbered correspond to number of archetypes) (comment out the ones not loaded yet)
path2 = r"XX"
path3 = r"XX"
path4 = r"XX"
path5 = r"XX"
path6 = r"XX"
path7 = r"XX"
path8 = r"XX"
path9 = r"XX"
path10 = r"XX"
path11 = r"XX"


# List of all model paths (comment out the ones not loaded yet)
model_paths = [
    path2, path3, path4, 
    path5, path6, 
    path7, path8, path9, path10, path11
]

# For each model path, load the final ELBO value

ELBO_list = []

for path in model_paths:
    with open(path, "rb") as f:#read binary
        ELBO = result["ELBO"]
        
        ELBO_list.append(ELBO)

# %% [markdown]
# Plot final elbo values on a graph to identify the best model performance

# %%
import matplotlib.pyplot as plt

archetype_nums = [i + 2 for i in range(len(ELBO_list))] #first number of arhcetypes is 2
final_elbos = [elbo[-1] if isinstance(elbo, (list, np.ndarray)) else elbo for elbo in ELBO_list] #accessing the last value of each elbo list

plt.figure(figsize=(8, 5))
plt.plot(archetype_nums, final_elbos, marker='o')
plt.xlabel('Number of archetypes')
plt.ylabel('Final ELBO value')
plt.title('Final ELBO value vs Number of Archetypes')
plt.show()
